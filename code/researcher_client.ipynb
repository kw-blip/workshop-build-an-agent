# %% [markdown]
# # Research Agent Client

# %%
# %pip install -r ../requirements.txt > /dev/null
from dotenv import load_dotenv
_ = load_dotenv("../variables.env")
_ = load_dotenv("../secrets.env")
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import logging
logging.basicConfig(level=logging.INFO)

from IPython.display import Markdown

from docgen_agent.researcher import ResearcherState, graph

# %% [markdown]
# ## Inputs
#
# Try making changes to the agent request.

# %%
topic = "Examples of AI agents in various industries."

# %% [markdown]
# ## Ask the Agent
#
# Here, we will send your request to the agent. The agent will print log messages to let you know what it is up to. Expect this step to take a few minutes.

# %%
state = ResearcherState(
    topic=topic,
    number_of_queries=3,
)

state = await graph.ainvoke(state)
# Out:
# INFO:docgen_agent.researcher:Calling model.
# INFO:docgen_agent.researcher:Executing tool calls.
# INFO:docgen_agent.researcher:Executing tool call: search_tavily
# INFO:docgen_agent.tools:Searching the web using the Tavily API
# INFO:docgen_agent.tools:Searching for query: AI agents in healthcare 2024: technical architecture and real-time decision-making frameworks
# INFO:docgen_agent.tools:Searching for query: AI agent implementations in manufacturing 2024: comparison with traditional automation systems and reinforcement learning applications
# INFO:docgen_agent.tools:Searching for query: AI agent frameworks for financial services 2024: technical specifications of transformer-based models and regulatory compliance challenges
# INFO:httpx:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.tavily.com/search "HTTP/1.1 200 OK"
# INFO:docgen_agent.researcher:Calling model.

# %% [markdown]
# ## Examine the results
#
# The researcher adds the research results to the chat log so that it is available to all later steps.
#
# Let's examine our conversation with the researcher.
#
# You should see at least three messages:
# 1. A message from the model requesting a tool call.
# 2. A tool_call message with the raw source data.
# 3. A message from the assistant, summarizing the results.

# %%
for message in state["messages"]:
    print("ROLE: ", getattr(message, "role", "tool_call"))
    print(message.content[:500] or message.additional_kwargs)
    print("")
# Out:
# ROLE:  assistant
#
#
#
# ROLE:  tool_call
# "Sources:\n\nSource [PDF] Artificial Intelligent Agent Architecture and Clinical Decision-Making ...:\n===\nURL: https://www.cureus.com/articles/266768-artificial-intelligent-agent-architecture-and-clinical-decision-making-in-the-healthcare-sector.pdf\n===\nMost relevant content from source: Categories: Other, Healthcare Technology Keywords: cognition, ai, physician decision-making, physician metacognition, intelligent agents Introduction With recent developments in artificial intelligence (AI),
#
# ROLE:  assistant
# Here are the three targeted search queries generated based on your requirements:
#
# 1. **"AI agent technical architecture in healthcare 2024: multimodal data integration frameworks (e.g., medical imaging + EHR) and real-time clinical decision-making algorithms"**
#    *Focus*: Technical specifications, recent implementations, and comparisons with traditional clinical systems.
#
# 2. **"AI agent applications in manufacturing 2024: reinforcement learning vs. rule-based automation for predictive mainten
